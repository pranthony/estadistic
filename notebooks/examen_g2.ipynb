# %%
from desc.frecuence import FrequencyAnalysis

# %% [markdown]
# # Estadística y Probabilidades (G2) Examen-Unidad 1
#
# ##  2 Responder los siguientes casos
#
# ### a) Considere los datos de las medidas de altura de los estiantes de Economía de la Unheval en cm.

# %%
medidas = [
    151, 152, 154, 158, 159, 170, 152, 158, 189, 190,
    161, 162, 163, 163, 165, 160, 162, 163, 188, 182,
    166, 166, 166, 167, 167, 178, 173, 167, 187, 178,
    168, 168, 168, 168, 168, 175, 184, 168, 170, 176,
    169, 169, 169, 169, 170, 172, 188, 169, 156, 173,
    170, 170, 171, 171, 187, 168, 150, 174, 177, 170,
    173, 173, 174, 174, 188, 167, 156, 171, 181, 169,
    176, 176, 176, 177, 190, 166, 166, 177, 185, 168,
    179, 179, 180, 180, 190, 186, 162, 181, 152, 166,
    182, 182, 183, 185, 187, 150, 158, 185, 159, 161
]

analisys_medidas = FrequencyAnalysis(medidas)

# %% [markdown]
# #### a.1. Construir una tabla de frecuencia, usando el algoritmode Sturges

# %%
analisys_medidas.create_distribution_table()
# Out:
#                  I     mi  fi    hi    %i   Fi    Hi     $i
# 0  150.00 - 155.00  152.5   7  0.07   7.0    7  0.07    7.0
# 1  155.00 - 160.00  157.5   7  0.07   7.0   14  0.14   14.0
# 2  160.00 - 165.00  162.5   9  0.09   9.0   23  0.23   23.0
# 3  165.00 - 170.00  167.5  25  0.25  25.0   48  0.48   48.0
# 4  170.00 - 175.00  172.5  17  0.17  17.0   65  0.65   65.0
# 5  175.00 - 180.00  177.5  12  0.12  12.0   77  0.77   77.0
# 6  180.00 - 185.00  182.5   9  0.09   9.0   86  0.86   86.0
# 7  185.00 - 190.00  187.5  14  0.14  14.0  100  1.00  100.0

# %% [markdown]
# #### a.3. Elaborar el histiograma de frecuencia relativa, genera el poligono de frecuencia absoluta y genera las gráficas de torta para la frecuencia porcentual

# %%
analisys_medidas.plot_histogram(relative=True)

# %%
analisys_medidas.plot_ogive()

# %%
# angulo para cada porcion del diagrama de torta
print(analisys_medidas.relative_freq)
analisys_medidas.relative_freq * 360
# Out:
# [0.07 0.07 0.09 0.25 0.17 0.12 0.09 0.14]
# array([25.2, 25.2, 32.4, 90. , 61.2, 43.2, 32.4, 50.4])

# %%
analisys_medidas.plot_pie_diagram()

# %% [markdown]
# ### b) Las velocidades de los rayos X para tratamiento médico en el hospital Hermilio Valdizán de Huánuco fueron registrados en millisegundos (1/1000 de un segundo) y fueron

# %%
velocity = [
    0.3, 0.9, 1.1, 1.7, 1.5, 0.8, 0.7, 1.1,
    0.8, 1.0, 1.3, 0.2, 1.6, 0.1, 0.5, 0.7,
    1.2, 1.5, 0.8, 0.9, 0.7, 0.5, 1.1, 1.5,
    0.1, 1.4, 0.7, 0.8, 0.6, 1.3, 1.2, 1.4,
    1.8, 0.7, 0.9, 1.0, 0.3, 1.2, 1.8, 1.0
]

desc_velocity = FrequencyAnalysis(velocity, class_width=0.25)

# %% [markdown]
# #### b.1. Construya una distribución de frecuencia usando intervalos de tamaño 0.25 millisegundos

# %%
desc_velocity.create_distribution_table()
# Out:
#              I     mi  fi     hi    %i  Fi     Hi     $i
# 0  0.10 - 0.35  0.225   5  0.125  12.5   5  0.125   12.5
# 1  0.35 - 0.60  0.475   2  0.050   5.0   7  0.175   17.5
# 2  0.60 - 0.85  0.725  10  0.250  25.0  17  0.425   42.5
# 3  0.85 - 1.10  0.975   6  0.150  15.0  23  0.575   57.5
# 4  1.10 - 1.35  1.225   8  0.200  20.0  31  0.775   77.5
# 5  1.35 - 1.60  1.475   5  0.125  12.5  36  0.900   90.0
# 6  1.60 - 1.85  1.725   4  0.100  10.0  40  1.000  100.0

# %% [markdown]
# #### b.2. Construya un histograma y un poligono de frecuencia a partir de los datos

# %%
desc_velocity.plot_histogram(polygon=True)

# %% [markdown]
# #### b.3. Construya una ojiva de frecuencia relativa (mayor que) a partir de los datos

# %%
from Types import FrequencyType

desc_velocity.plot_ogive(FrequencyType.ABSOLUTE_CUMULATIVE.value)
